# %%
import pandas as pd

# %%
df = pd.read_csv('data/survey_results_public.csv')
schema_df = pd.read_csv('data/survey_results_schema.csv')

# %%
schema_df
# Out:
#           Column                                       QuestionText
# 0     Respondent  Randomized respondent ID number (not in order ...
# 1     MainBranch  Which of the following options best describes ...
# 2       Hobbyist                            Do you code as a hobby?
# 3    OpenSourcer        How often do you contribute to open source?
# 4     OpenSource  How do you feel about the quality of open sour...
# ..           ...                                                ...
# 80     Sexuality  Which of the following do you currently identi...
# 81     Ethnicity  Which of the following do you identify as? Ple...
# 82    Dependents  Do you have any dependents (e.g., children, el...
# 83  SurveyLength  How do you feel about the length of the survey...
# 84    SurveyEase  How easy or difficult was this survey to compl...
#
# [85 rows x 2 columns]

# %%
pd.set_option('display.max_columns',85)
pd.set_option('display.max_rows',85)

# %%
df.set_index('Ethnicity')
# Out:
#                                                     Respondent  \
# Ethnicity
# NaN                                                          1
# NaN                                                          2
# NaN                                                          3
# White or of European descent                                 4
# White or of European descent;Multiracial                     5
# ...                                                        ...
# NaN                                                      88377
# NaN                                                      88601
# NaN                                                      88802
# NaN                                                      88816
# Hispanic or Latino/Latina;White or of European ...       88863
#
#                                                                                            MainBranch  \
# Ethnicity
# ...

# %%
df.shape
# Out:
# (88883, 85)

# %%
df['Hobbyist']
# Out:
# 0        Yes
# 1         No
# 2        Yes
# 3         No
# 4        Yes
#         ...
# 88878    Yes
# 88879     No
# 88880     No
# 88881     No
# 88882    Yes
# Name: Hobbyist, Length: 88883, dtype: object

# %%
df['Hobbyist'].value_counts()
# Out:
# Yes    71257
# No     17626
# Name: Hobbyist, dtype: int64

# %%
df['Hobbyist']
# Out:
# 0        Yes
# 1         No
# 2        Yes
# 3         No
# 4        Yes
#         ...
# 88878    Yes
# 88879     No
# 88880     No
# 88881     No
# 88882    Yes
# Name: Hobbyist, Length: 88883, dtype: object

# %%
df.loc[0:800,'Hobbyist'] # no wrapping the rows in brackets casues the error
# Out:
# 0      Yes
# 1       No
# 2      Yes
# 3       No
# 4      Yes
#       ...
# 796    Yes
# 797     No
# 798    Yes
# 799    Yes
# 800    Yes
# Name: Hobbyist, Length: 801, dtype: object

# %%
df.loc[0:85,'Hobbyist'] # slices and shows top 5 and bottom 5 from 85 onwards SLICING is INCLUSIVE
# Out:
# 0     Yes
# 1      No
# 2     Yes
# 3      No
# 4     Yes
#      ...
# 81    Yes
# 82    Yes
# 83     No
# 84    Yes
# 85    Yes
# Name: Hobbyist, Length: 86, dtype: object

# %%
df.loc[0:3,'Hobbyist':'Country']
# Out:
#   Hobbyist              OpenSourcer  \
# 0      Yes                    Never
# 1       No  Less than once per year
# 2      Yes                    Never
# 3       No                    Never
#
#                                           OpenSource  \
# 0  The quality of OSS and closed source software ...
# 1  The quality of OSS and closed source software ...
# 2  The quality of OSS and closed source software ...
# 3  The quality of OSS and closed source software ...
#
#                                Employment                 Country
# 0  Not employed, and not looking for work          United Kingdom
# 1      Not employed, but looking for work  Bosnia and Herzegovina
# 2                      Employed full-time                Thailand
# 3                      Employed full-time           United States

# %%
df.set_index('Respondent',inplace=True)

# %%
df
# Out:
#                                                    MainBranch Hobbyist  \
# Respondent
# 1                      I am a student who is learning to code      Yes
# 2                      I am a student who is learning to code       No
# 3           I am not primarily a developer, but I write co...      Yes
# 4                              I am a developer by profession       No
# 5                              I am a developer by profession      Yes
# ...                                                       ...      ...
# 88377                                                     NaN      Yes
# 88601                                                     NaN       No
# 88802                                                     NaN       No
# 88816                                                     NaN       No
# 88863                                                     NaN      Yes
#
#                                                   OpenSourcer  \
# Respondent
# ...

# %%
df.loc[1]
# Out:
# MainBranch                           I am a student who is learning to code
# Hobbyist                                                                Yes
# OpenSourcer                                                           Never
# OpenSource                The quality of OSS and closed source software ...
# Employment                           Not employed, and not looking for work
# Country                                                      United Kingdom
# Student                                                                  No
# EdLevel                                           Primary/elementary school
# UndergradMajor                                                          NaN
# EduOther                  Taught yourself a new language, framework, or ...
# OrgSize                                                                 NaN
# DevType                                                                 NaN
# ...

# %%
schema_df.set_index('Column' , inplace=True)

# %%
schema_df.loc['MgrIdiot']
# Out:
# QuestionText    How confident are you that your manager knows ...
# Name: MgrIdiot, dtype: object

# %%
schema_df.loc['MgrIdiot','QuestionText']
# Out:
# 'How confident are you that your manager knows what they’re doing?'

# %%
schema_df.sort_index(ascending=True)
# Out:
#                                                              QuestionText
# Column
# Age                     What is your age (in years)? If you prefer not...
# Age1stCode              At what age did you write your first line of c...
# BetterLife              Do you think people born today will have a bet...
# BlockchainIs            Blockchain / cryptocurrency technology is prim...
# BlockchainOrg           How is your organization thinking about or imp...
# CareerSat               Overall, how satisfied are you with your caree...
# CodeRev                          Do you review code as part of your work?
# CodeRevHrs              On average, how many hours per week do you spe...
# CompFreq                 Is that compensation weekly, monthly, or yearly?
# CompTotal               What is your current total compensation (salar...
# Containers              How do you use containers (Docker, Open Contai...
# ConvertedComp           Salary converted to annual USD salaries using ...
# ...

# %%
df.sort_index(ascending=False)
# Out:
#                                                    MainBranch Hobbyist  \
# Respondent
# 88883                          I am a developer by profession      Yes
# 88882                          I am a developer by profession      Yes
# 88881                          I am a developer by profession      Yes
# 88880       I am not primarily a developer, but I write co...      Yes
# 88879                          I am a developer by profession      Yes
# ...                                                       ...      ...
# 5                              I am a developer by profession      Yes
# 4                              I am a developer by profession       No
# 3           I am not primarily a developer, but I write co...      Yes
# 2                      I am a student who is learning to code       No
# 1                      I am a student who is learning to code      Yes
#
#                            OpenSourcer  \
# Respondent
# 88883       Once a month or more often
# ...

# %%
high_salary = (df['ConvertedComp']>=200000)

# %%
schema_df.loc['ConvertedComp','QuestionText']
# Out:
# 'Salary converted to annual USD salaries using the exchange rate on 2019-02-01, assuming 12 working months and 50 working weeks.'

# %%
df.loc[high_salary,['Country','EdLevel','LanguageWorkedWith','ConvertedComp']] 
# respondent is the custom index thus it is no longer a column and won't be 
#displayed if we input it in the column list
# Out:
#                    Country                                            EdLevel  \
# Respondent
# 6                   Canada           Bachelor’s degree (BA, BS, B.Eng., etc.)
# 16          United Kingdom        Master’s degree (MA, MS, M.Eng., MBA, etc.)
# 32           United States                                   Associate degree
# 58           United States           Bachelor’s degree (BA, BS, B.Eng., etc.)
# 100                 Canada  Some college/university study without earning ...
# ...                    ...                                                ...
# 88867             Portugal        Master’s degree (MA, MS, M.Eng., MBA, etc.)
# 88868              Germany  Some college/university study without earning ...
# 88874        United States           Bachelor’s degree (BA, BS, B.Eng., etc.)
# 88877        United States           Bachelor’s degree (BA, BS, B.Eng., etc.)
# 88882          Netherlands        Master’s degree (MA, MS, M.Eng., MBA, etc.)
#
# ...

# %%
country_specified = (df['Country']=='India') | (df['Country']=='United States') | (df['Country']=='Canada')

# %%
df.loc[country_specified,['Country','EdLevel','LanguageWorkedWith','ConvertedComp']]
# Out:
#                   Country                                            EdLevel  \
# Respondent
# 4           United States           Bachelor’s degree (BA, BS, B.Eng., etc.)
# 6                  Canada           Bachelor’s degree (BA, BS, B.Eng., etc.)
# 8                   India           Bachelor’s degree (BA, BS, B.Eng., etc.)
# 10                  India        Master’s degree (MA, MS, M.Eng., MBA, etc.)
# 12                 Canada  Some college/university study without earning ...
# ...                   ...                                                ...
# 85182              Canada                                                NaN
# 85642       United States                                   Associate degree
# 86012               India        Master’s degree (MA, MS, M.Eng., MBA, etc.)
# 88282       United States  Some college/university study without earning ...
# 88377              Canada                          Primary/elementary school
#
# ...

# %%
#filter multiple values
countries=['India','United States','Canada']
altfilt= df['Country'].isin(countries)
df.loc[altfilt,'Country']
# Out:
# Respondent
# 4        United States
# 6               Canada
# 8                India
# 10               India
# 12              Canada
#              ...
# 85182           Canada
# 85642    United States
# 86012            India
# 88282    United States
# 88377           Canada
# Name: Country, Length: 33405, dtype: object

# %%
# filter strings
filtew = df["LanguageWorkedWith"].str.contains("Python",na=False)

# %%
df.loc[filtew,"LanguageWorkedWith"]
# Out:
# Respondent
# 1                          HTML/CSS;Java;JavaScript;Python
# 2                                      C++;HTML/CSS;Python
# 4                                      C;C++;C#;Python;SQL
# 5              C++;HTML/CSS;Java;JavaScript;Python;SQL;VBA
# 8        Bash/Shell/PowerShell;C;C++;HTML/CSS;Java;Java...
#                                ...
# 84539    Bash/Shell/PowerShell;C;C++;HTML/CSS;Java;Java...
# 85738      Bash/Shell/PowerShell;C++;Python;Ruby;Other(s):
# 86566      Bash/Shell/PowerShell;HTML/CSS;Python;Other(s):
# 87739             C;C++;HTML/CSS;JavaScript;PHP;Python;SQL
# 88212                           HTML/CSS;JavaScript;Python
# Name: LanguageWorkedWith, Length: 36443, dtype: object

# %%
df.columns
# Out:
# Index(['MainBranch', 'Hobbyist', 'OpenSourcer', 'OpenSource', 'Employment',
#        'Country', 'Student', 'EdLevel', 'UndergradMajor', 'EduOther',
#        'OrgSize', 'DevType', 'YearsCode', 'Age1stCode', 'YearsCodePro',
#        'CareerSat', 'JobSat', 'MgrIdiot', 'MgrMoney', 'MgrWant', 'JobSeek',
#        'LastHireDate', 'LastInt', 'FizzBuzz', 'JobFactors', 'ResumeUpdate',
#        'CurrencySymbol', 'CurrencyDesc', 'CompTotal', 'CompFreq',
#        'ConvertedComp', 'WorkWeekHrs', 'WorkPlan', 'WorkChallenge',
#        'WorkRemote', 'WorkLoc', 'ImpSyn', 'CodeRev', 'CodeRevHrs', 'UnitTests',
#        'PurchaseHow', 'PurchaseWhat', 'LanguageWorkedWith',
#        'LanguageDesireNextYear', 'DatabaseWorkedWith',
#        'DatabaseDesireNextYear', 'PlatformWorkedWith',
#        'PlatformDesireNextYear', 'WebFrameWorkedWith',
#        'WebFrameDesireNextYear', 'MiscTechWorkedWith',
#        'MiscTechDesireNextYear', 'DevEnviron', 'OpSys', 'Containers',
# ...

# %%
df.count()
# Out:
# MainBranch                88331
# Hobbyist                  88883
# OpenSourcer               88883
# OpenSource                86842
# Employment                87181
# Country                   88751
# Student                   87014
# EdLevel                   86390
# UndergradMajor            75614
# EduOther                  84260
# OrgSize                   71791
# DevType                   81335
# YearsCode                 87938
# Age1stCode                87634
# YearsCodePro              74331
# CareerSat                 72847
# JobSat                    70988
# MgrIdiot                  61159
# MgrMoney                  61157
# MgrWant                   61232
# JobSeek                   80555
# LastHireDate              79854
# LastInt                   67155
# FizzBuzz                  71344
# JobFactors                79371
# ResumeUpdate              77877
# CurrencySymbol            71392
# CurrencyDesc              71392
# CompTotal                 55945
# ...

# %%
df.sort_values(by='Country')
# Out:
#                                 MainBranch Hobbyist              OpenSourcer  \
# Respondent
# 39258       I am a developer by profession      Yes  Less than once per year
# 63129       I am a developer by profession      Yes                    Never
# 85715       I am a developer by profession       No  Less than once per year
# 50767       I am a developer by profession       No  Less than once per year
# 2782                                   NaN      Yes  Less than once per year
# ...                                    ...      ...                      ...
# 88062                                  NaN       No                    Never
# 88076                                  NaN       No                    Never
# 88601                                  NaN       No                    Never
# 88802                                  NaN       No                    Never
# 88816                                  NaN       No                    Never
#
# ...

# %%
countries=df['Country'].tolist()
print(countries)
# Out:
# ['United Kingdom', 'Bosnia and Herzegovina', 'Thailand', 'United States', 'Ukraine', 'Canada', 'Ukraine', 'India', 'New Zealand', 'India', 'Antigua and Barbuda', 'Canada', 'United States', 'Germany', 'India', 'United Kingdom', 'Australia', 'Russian Federation', 'Brazil', 'Lithuania', 'Canada', 'United States', 'United States', 'Israel', 'South Africa', 'United States', 'Colombia', 'Turkey', 'United States', 'Switzerland', 'Canada', 'United States', 'Argentina', 'Sri Lanka', 'United States', 'Germany', 'Canada', 'Czech Republic', 'United States', 'Denmark', 'Malaysia', 'Bangladesh', 'Spain', 'Germany', 'United States', 'United States', 'United States', 'Russian Federation', 'Serbia', 'India', 'United States', 'Poland', 'United States', 'Sweden', 'Sri Lanka', 'China', 'France', 'United States', 'Argentina', 'United States', 'United States', 'Netherlands', 'Italy', 'Czech Republic', 'India', 'Germany', 'Australia', 'India', 'Switzerland', 'United States', 'Philippines', 'New Zealand', '
# ...

# %%
df.nlargest(10,'ConvertedComp')
# Out:
#                                 MainBranch Hobbyist  \
# Respondent
# 58          I am a developer by profession      Yes
# 102         I am a developer by profession       No
# 166         I am a developer by profession      Yes
# 436         I am a developer by profession      Yes
# 452         I am a developer by profession      Yes
# 491         I am a developer by profession      Yes
# 539         I am a developer by profession       No
# 770         I am a developer by profession      Yes
# 789         I am a developer by profession      Yes
# 1232        I am a developer by profession       No
#
#                                                   OpenSourcer  \
# Respondent
# 58                                 Once a month or more often
# 102                                                     Never
# 166                                   Less than once per year
# 436                                   Less than once per year
# ...

# %%
df['ConvertedComp'].nlargest(10)
# Out:
# Respondent
# 58      2000000.0
# 102     2000000.0
# 166     2000000.0
# 436     2000000.0
# 452     2000000.0
# 491     2000000.0
# 539     2000000.0
# 770     2000000.0
# 789     2000000.0
# 1232    2000000.0
# Name: ConvertedComp, dtype: float64

# %%
df['ConvertedComp'].median()
# Out:
# 57287.0

# %%
df.median()
# Out:
# /var/folders/xz/9p0qz5sj0b5gs2j359d55vd80000gn/T/ipykernel_37041/530051474.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df.median()
# CompTotal        62000.0
# ConvertedComp    57287.0
# WorkWeekHrs         40.0
# CodeRevHrs           4.0
# Age                 29.0
# dtype: float64

# %%
df.describe()
# Out:
#           CompTotal  ConvertedComp   WorkWeekHrs    CodeRevHrs           Age
# count  5.594500e+04   5.582300e+04  64503.000000  49790.000000  79210.000000
# mean   5.519014e+11   1.271107e+05     42.127197      5.084308     30.336699
# std    7.331926e+13   2.841523e+05     37.287610      5.513931      9.178390
# min    0.000000e+00   0.000000e+00      1.000000      0.000000      1.000000
# 25%    2.000000e+04   2.577750e+04     40.000000      2.000000     24.000000
# 50%    6.200000e+04   5.728700e+04     40.000000      4.000000     29.000000
# 75%    1.200000e+05   1.000000e+05     44.750000      6.000000     35.000000
# max    1.000000e+16   2.000000e+06   4850.000000     99.000000     99.000000

# %%
df.mean()
# Out:
# /var/folders/xz/9p0qz5sj0b5gs2j359d55vd80000gn/T/ipykernel_37041/3698961737.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df.mean()
# CompTotal        5.519014e+11
# ConvertedComp    1.271107e+05
# WorkWeekHrs      4.212720e+01
# CodeRevHrs       5.084308e+00
# Age              3.033670e+01
# dtype: float64

# %%
df['ConvertedComp'].count()
# Out:
# 55823

# %%
df['Hobbyist'].value_counts()
# Out:
# Yes    71257
# No     17626
# Name: Hobbyist, dtype: int64

# %%
df['ConvertedComp'].value_counts()
# Out:
# 2000000.0    709
# 1000000.0    558
# 120000.0     502
# 100000.0     480
# 150000.0     434
#             ...
# 411096.0       1
# 261228.0       1
# 82322.0        1
# 66424.0        1
# 588012.0       1
# Name: ConvertedComp, Length: 9162, dtype: int64

# %%
df['SocialMedia'].value_counts()
# Out:
# Reddit                      14374
# YouTube                     13830
# WhatsApp                    13347
# Facebook                    13178
# Twitter                     11398
# Instagram                    6261
# I don't use social media     5554
# LinkedIn                     4501
# WeChat 微信                     667
# Snapchat                      628
# VK ВКонта́кте                 603
# Weibo 新浪微博                     56
# Youku Tudou 优酷                 21
# Hello                          19
# Name: SocialMedia, dtype: int64

# %%
schema_df.loc['SocialMedia']
# Out:
# QuestionText    What social media site do you use the most?
# Name: SocialMedia, dtype: object

# %%
df['SocialMedia'].value_counts(normalize=True)
# Out:
# Reddit                      0.170233
# YouTube                     0.163791
# WhatsApp                    0.158071
# Facebook                    0.156069
# Twitter                     0.134988
# Instagram                   0.074150
# I don't use social media    0.065777
# LinkedIn                    0.053306
# WeChat 微信                   0.007899
# Snapchat                    0.007437
# VK ВКонта́кте               0.007141
# Weibo 新浪微博                  0.000663
# Youku Tudou 优酷              0.000249
# Hello                       0.000225
# Name: SocialMedia, dtype: float64

# %%
df.std()
# Out:
# /var/folders/xz/9p0qz5sj0b5gs2j359d55vd80000gn/T/ipykernel_37041/3390915376.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df.std()
# CompTotal        7.331926e+13
# ConvertedComp    2.841523e+05
# WorkWeekHrs      3.728761e+01
# CodeRevHrs       5.513931e+00
# Age              9.178390e+00
# dtype: float64

# %%
df.describe()
# Out:
#           CompTotal  ConvertedComp   WorkWeekHrs    CodeRevHrs           Age
# count  5.594500e+04   5.582300e+04  64503.000000  49790.000000  79210.000000
# mean   5.519014e+11   1.271107e+05     42.127197      5.084308     30.336699
# std    7.331926e+13   2.841523e+05     37.287610      5.513931      9.178390
# min    0.000000e+00   0.000000e+00      1.000000      0.000000      1.000000
# 25%    2.000000e+04   2.577750e+04     40.000000      2.000000     24.000000
# 50%    6.200000e+04   5.728700e+04     40.000000      4.000000     29.000000
# 75%    1.200000e+05   1.000000e+05     44.750000      6.000000     35.000000
# max    1.000000e+16   2.000000e+06   4850.000000     99.000000     99.000000

# %%
df.count()
# Out:
# MainBranch                88331
# Hobbyist                  88883
# OpenSourcer               88883
# OpenSource                86842
# Employment                87181
# Country                   88751
# Student                   87014
# EdLevel                   86390
# UndergradMajor            75614
# EduOther                  84260
# OrgSize                   71791
# DevType                   81335
# YearsCode                 87938
# Age1stCode                87634
# YearsCodePro              74331
# CareerSat                 72847
# JobSat                    70988
# MgrIdiot                  61159
# MgrMoney                  61157
# MgrWant                   61232
# JobSeek                   80555
# LastHireDate              79854
# LastInt                   67155
# FizzBuzz                  71344
# JobFactors                79371
# ResumeUpdate              77877
# CurrencySymbol            71392
# CurrencyDesc              71392
# CompTotal                 55945
# ...

# %%
df['ConvertedComp'].count()
# Out:
# 55823

# %%
df['Hobbyist'].value_counts()
# Out:
# Yes    71257
# No     17626
# Name: Hobbyist, dtype: int64

# %%
df.value_counts()
# Out:
# MainBranch                                                                     Hobbyist  OpenSourcer                                         OpenSource                                                                       Employment          Country        Student         EdLevel                                                 UndergradMajor                                                         EduOther                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  OrgSize                   DevType           
# ...

# %%
df['SocialMedia'].value_counts(normalize=True)
# Out:
# Reddit                      0.170233
# YouTube                     0.163791
# WhatsApp                    0.158071
# Facebook                    0.156069
# Twitter                     0.134988
# Instagram                   0.074150
# I don't use social media    0.065777
# LinkedIn                    0.053306
# WeChat 微信                   0.007899
# Snapchat                    0.007437
# VK ВКонта́кте               0.007141
# Weibo 新浪微博                  0.000663
# Youku Tudou 优酷              0.000249
# Hello                       0.000225
# Name: SocialMedia, dtype: float64

# %%
# group by function
country_grp=df.groupby(['Country'])

# %%
country_grp.get_group('United States')
# Out:
#                                 MainBranch Hobbyist  \
# Respondent
# 4           I am a developer by profession       No
# 13          I am a developer by profession      Yes
# 22          I am a developer by profession      Yes
# 23          I am a developer by profession      Yes
# 26          I am a developer by profession      Yes
# ...                                    ...      ...
# 78292                                  NaN       No
# 82717                                  NaN       No
# 83397                                  NaN      Yes
# 85642                                  NaN       No
# 88282                                  NaN      Yes
#
#                                                   OpenSourcer  \
# Respondent
# 4                                                       Never
# 13          Less than once a month but more than once per ...
# 22                                    Less than once per year
# ...
